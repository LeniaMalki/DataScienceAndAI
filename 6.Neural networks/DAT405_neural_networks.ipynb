# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.utils import np_utils
import tensorflow as tf 
from tensorflow.keras import optimizers

batch_size = 128
num_classes = 10
epochs = 10

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# convert class vectors to binary class matrices
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

## Define model ##
model = Sequential()

model.add(Flatten())
model.add(Dense(125, activation = 'relu'))
model.add(Dense(100, activation = 'relu'))
model.add(Dense(50, activation = 'relu'))
model.add(Dense(num_classes, activation='softmax'))


model.compile(loss=keras.losses.categorical_crossentropy,
               optimizer=tf.keras.optimizers.SGD(learning_rate = 0.1),
               metrics=['accuracy'])

fit_info = model.fit(x_train, y_train,
           batch_size=batch_size,
           epochs=epochs,
           verbose=1,
           validation_data=(x_test, y_test))

# Display our model using the summary function. The parameters include biases and weights.
model.summary()

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss: {}, Test accuracy {}'.format(score[0], score[1]))
# Out:
# Epoch 1/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4744 - accuracy: 0.8601 - val_loss: 0.2655 - val_accuracy: 0.9173
# Epoch 2/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1899 - accuracy: 0.9431 - val_loss: 0.1480 - val_accuracy: 0.9562
# Epoch 3/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1395 - accuracy: 0.9588 - val_loss: 0.1226 - val_accuracy: 0.9606
# Epoch 4/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1100 - accuracy: 0.9672 - val_loss: 0.1031 - val_accuracy: 0.9683
# Epoch 5/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0912 - accuracy: 0.9734 - val_loss: 0.1067 - val_accuracy: 0.9666
# Epoch 6/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0771 - accuracy: 0.9764 - val_loss: 0.1018 - val_accuracy: 0.9693
# Epoch 7/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0659 - accuracy: 0.9802 - val_loss: 0.0979 - val_accuracy: 0.9669
# Epoch 8/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0567 - accuracy: 0.9829 - val_loss: 0.0807 - val_accuracy: 0.9749
# Epoch 9/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0499 - accuracy: 0.9850 - val_loss: 0.0812 - val_accuracy: 0.9744
# Epoch 10/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0435 - accuracy: 0.9872 - val_loss: 0.0842 - val_accuracy: 0.9742
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 125)               98125
#
#  dense_1 (Dense)             (None, 100)               12600
#
#  dense_2 (Dense)             (None, 50)                5050
#
#  dense_3 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 116,285
# Trainable params: 116,285
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.08420564234256744, Test accuracy 0.9742000102996826
