# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.utils import np_utils
import tensorflow as tf 
from tensorflow.keras import optimizers

batch_size = 128
num_classes = 10
epochs = 10

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# convert class vectors to binary class matrices
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

## Define model ##
model = Sequential()

model.add(Flatten())
model.add(Dense(125, activation = 'relu'))
model.add(Dense(100, activation = 'relu'))
model.add(Dense(50, activation = 'relu'))
model.add(Dense(num_classes, activation='softmax'))


model.compile(loss=keras.losses.categorical_crossentropy,
               optimizer=tf.keras.optimizers.SGD(learning_rate = 0.1),
               metrics=['accuracy'])

fit_info = model.fit(x_train, y_train,
           batch_size=batch_size,
           epochs=epochs,
           verbose=1,
           validation_data=(x_test, y_test))

# Display our model using the summary function. The parameters include biases and weights.
model.summary()

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss: {}, Test accuracy {}'.format(score[0], score[1]))
# Out:
# Epoch 1/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4603 - accuracy: 0.8650 - val_loss: 0.2156 - val_accuracy: 0.9386
# Epoch 2/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1860 - accuracy: 0.9441 - val_loss: 0.1441 - val_accuracy: 0.9549
# Epoch 3/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1352 - accuracy: 0.9599 - val_loss: 0.1281 - val_accuracy: 0.9593
# Epoch 4/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1080 - accuracy: 0.9677 - val_loss: 0.1000 - val_accuracy: 0.9684
# Epoch 5/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0893 - accuracy: 0.9730 - val_loss: 0.0968 - val_accuracy: 0.9687
# Epoch 6/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0762 - accuracy: 0.9768 - val_loss: 0.1175 - val_accuracy: 0.9642
# Epoch 7/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0653 - accuracy: 0.9811 - val_loss: 0.1205 - val_accuracy: 0.9622
# Epoch 8/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0567 - accuracy: 0.9827 - val_loss: 0.0859 - val_accuracy: 0.9735
# Epoch 9/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0502 - accuracy: 0.9850 - val_loss: 0.0951 - val_accuracy: 0.9684
# Epoch 10/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0427 - accuracy: 0.9869 - val_loss: 0.0755 - val_accuracy: 0.9764
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_10 (Flatten)        (None, 784)               0
#
#  dense_40 (Dense)            (None, 125)               98125
#
#  dense_41 (Dense)            (None, 100)               12600
#
#  dense_42 (Dense)            (None, 50)                5050
#
#  dense_43 (Dense)            (None, 10)                510
#
# =================================================================
# Total params: 116,285
# Trainable params: 116,285
# Non-trainable params: 0
# _________________________________________________________________
# Test loss: 0.07552897185087204, Test accuracy 0.9764000177383423
